# %% [markdown]
# <a href="https://colab.research.google.com/github/jayoung977/LA2020/blob/main/LA_CH1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1.1 Systems of Linear Equations (선형방정식계,연립일차방정식)**
#
#
# ---
# ##1) Linear Equation
# ---
#
#
# **system of linear equations (or a linear system)**: 동일한 변수들을 포한하는 하나또는 그이상의 선형방정식의 모임
#
# **solution set**:해집합;가능한 모든 해들을 모아놓은 집합
#
# **equivalent**: 동치;동일한 해집합을 갖는 경우
#
# **A system of linear equations**;선형방정식계 다음 만족
#
# 1.no solution, or   = inconsistent(해안갖음)
#
# 2.exactly one solution, or = consistent( 단 하나 해)
#
# 3.infinitely many solutions. = consistent(무한해)
#
#
# ---
# ##2) Matrix Notation ;행렬 표기법
# ---
# **coefficient matrix**: 계수행렬
#
# **augmented matrix** :첨가행렬(우변상수 포함)
#
#
# ---
# ##3) Solving a Linear System; 선형계 풀이법
# ---
# **Elementary Row Operations**; 기본 행연산
#
# 1.(**Replacement**);교체 Replace one row by the sum of itself and a multiple of another row. = Add to one row a multiple of another row.
#
# 2.(**Interchange**);교환 Interchange two rows.
#
# 3.(**Scaling**);스칼라곱 Multiply all entries in a row by a nonzero constant.
#
# ---
# ##4) Existence and Uniqueness of System of Equations; 해의 존재성,유일성
# ---
#
# 1.Is the system consistent; that is, does at least one solution exist?
# ;존재성=consistent?
#
# 2.If a solution exists, is it the only one; that is, is the solution unique?
# ;유일성, 유일한가?

# %% [markdown]
# #**1.2 Row Reduction and Echelon Forms; 행축약과 사다리꼴**
#
# - **leading entry**:선행성분,(영아닌 행에서)가장 왼쪽의 영아닌 성분
# ---
# ##1) Definition of Echelon Form ;사다리꼴 정의
# ---
# **REF** ;사다리꼴 echelon form (or row echelon form)
#
# 1.All nonzero rows are above any rows of all zeros.
#
# 2.Each leading entry of a row is in a column to the right of the leading entry of the row above it.
#
# 3.All entries in a column below a leading entry are zeros.
#
# **RREF**;기약사다리꼴reduced echelon form (or reduced row echelon form) -형태 유일/ 1
# 4.The leading entry in each nonzero row is 1.
#
# 5.Each leading 1 is the only nonzero entry in its column.
#
# **Theorem 1: Uniqueness of the Reduced Echelon Form**
# ;RREF의 유일성
#
# Each matrix is row equivalent to one and only one reduced echelon matrix.
# ;하나의 행렬과 행 동치인 RREF는 오직 하나이다.
#
# ---
# ##2) Pivot Position ;추축 위치
# ---
# **Definition of Pivot Position and Pivot Column**
#
# A **pivot position** in a matrix is a location in that corresponds to a leading 1 in the reduced echelon form of .
# ;RREF의 1에 해당
#
# A **pivot column** is a column of that contains a pivot position.
# ;`pivot position`를 포함하는 열
#
# ---
# ##3) Row Reduction Algorithm ;행축약 알고리즘
# ---
# 5단계/ 외울필요는 없고 하는 방법만 알면됨
#
# ---
# ##4) Solutions of Linear Systems ;선형계의 해
# ---
# **basic variables**;기본 변수, 행렬의 추축열에 대응하는 변수
# **free variable**;자유변수,나머지 변수 , 자유변수가 있다면 자유변수의 값에따라 선형계의 모든해가 달라진다.
#
# ---
# ##5) Parametric Descriptions of Solution Sets ;해집합의 매개변수 표현
# ---
# free variable(자유변수)가 parameters(매개변수)와 같은 역할을 한다.
#
# 선형계를 푼다=
# 1.해집합의 배개변수 표현구한다.또는
#
# 2.해집합이 공집합임을 판별한다.
# ; **매개변수로 표현 불가**
#
# ---
# ##6) Existence and Uniqueness Qeustions ;해존재성과 유일성
# ---
# linear system이 해를 갖는 필요충분 조건:
#
# [0 $\cdots$0 b]  b $\ne$ 0
#
# **If linear system is consistent**
# 1. a unique solution, when there are no free variables, or
# ;유일해,자유변수 없을때
# 2. infinitely many solutions, when there is at least one free variable.
# ;많은 해, 적어도 하나의 자유변수
#
# ---
# ##7) Using Row Reduction to Solve a Linear System ;행 축약을 통한 선형계의 해구하기
# ---
#
# 첨가행렬 >> REF >> RREF >> Linear System >> basic variables를 free variable로

# %% [markdown]
# #**1.3 Vector Equations; 벡터방정식**
# - vector will mean an ordered list of numbers;벡터 순서 중요
# ---
# ##1) Vectors in $R^2$
# ---
# **column vector** = **vector**
#
# `R`은 벡터 성분이 실수임을 의미, `지수 2`는 성분의 개수가 2개임을 의미
#
# **equal**:상동,필요충분조건은 대응 성분이 모두 같아야함
#
# ---
# ##2) Geometric Descriptions of $R^2$ ; 기하학적 표현
# ---
# 평면상 모든점들의 집합
#
# **Parallelogram Rule for Addition**; 합에대한 평행사변형 법칙
#
# ---
# ##3) Vectors in  $R^3$ and  $R^n$ ; n개의 entry를 갖는 벡터
# ---
#
# - $R^3$ : 3 * 1 colum vector
# - $R^n$ : n개ㅢ 실수로 이루어진 모든 순서있는 n짝의 집합, n * 1 colum vector
#
# **Algebraic Properties of $R^n$**;대수적 성질
# -교환,결합,분배되고,항등원,역원가짐
#
# ---
# ##4) Linear Combinations ; 선형결합
# ---
# **y = $c_1$$v_1$ +$\cdots$ + $c_p$$v_p$**
#
# ; 가중치 $c_1$,$\cdots$,$c_p$ 를 갖는 $v_1$,$\cdots$,$v_p$의 선형결합
#
# **Definition-Span**
#
# - **Span{$v_1$,$\cdots$,$v_p$}** =  $c_1$$v_1$ +$\cdots$ + $c_p$$v_p$
#
# ;$v_1$,$\cdots$,$v_p$에 의해서 형성된  $R^n$의 부분집합
#
# ---
# ##5) A Geometric Description of Span{v} ; Span{v} 와 Span{u,v}의 기하학적 표현
# ---
# - Span{v}; 원점을 지나는 직선
# - Span{u,v}; 원점을 지나는 평면

# %% [markdown]
# #**1.4 The Matrix Equation Ax = b; 행렬방정식**
# **Definition**
# Ax = [$a_1$,$\cdots$,$a_n$] $\begin{bmatrix} x_1 \\ \vdots \\ x_n \end{bmatrix}$ = $x_1$$a_1$ + $\cdots$ + $x_n$$a_n$
#
# ;A와 x의 곱은 A열들과 이에 대응하는 x의 성분들을 가중치로 하는 linear combination(선형결합)이다.
#
# **Theorem 3**
#
# - 1.the **same solution set** as the `vector equation`.
#
# - 2.which, in turn, has the **same solution set** as `the systme of linear euqations` whose augmented matrix is
#
#   =벡터 방정식과 선형방정식계와 동일 해집합
#
# ---
# ##1) Existence of Solutions; 해의 존재성
# ---
# Ax가 해를 갖기 위한 필요충분조건은 b가 A열의  linear combination인 것이다.
#
# **Theorem 4** 넷 다 동일의미임
#
# - 1.For each in , the equation has a solution.;Ax=b가 해를 갖는다.
#
# - 2.Each in is a linear combination of the columns of ;b는 A열의 선형결합이다.
#
# - 3.The columns of span ; A열들이 $R^m$을 생성한다.
#
# - 4.has a pivot position in every row; **coefficient**행렬일때 모든 행에 추축위치가 있다.
#
# ---
# ##2) Computation of Ax; Ax의 계산
# ---
# **Row-Vector Rule for Computing**;행-벡터 법칙
#
# ;행,열 대응성분끼리 곱함
#
# **Identity Matrix**; 항등행렬,1’s on the diagonal and 0’s elsewhere,
#
# ---
# ##3) Properties of the Matrix-Vector Product; 행렬과 벡터 곱 Ax의 성질
# ---
# **linearity개념과 유사 중요!**
# - A(u + v) = Au + Av ; **additiivty**
# - A(cu) = c(Au) ; **homogeneity**

# %% [markdown]
# #**1.5 Solution Sets of Linear Systems**
# ---
# ##1) Homogeneous Linear Systems; 동차선형계
# ---
# **homogeneous**;동치, 행렬을 영벡터로 쓸 수 있을때 Ax=0,항상 `consistent
# `(x=0)
#
# **trivial solution**;자명한 해, (x=0)
#
# **nontrivial solution**;자명하지 않은 해, Ax=0을 만족하는 영이 아닌 벡터가 존재하는가?
#
# - Ax=0가 nontrivial solution을 가질 필요충분 조건: 적어도 하나의 **free variable**을 갖음
#
# ---
# ##2) Parametric Vector Form; 매개변수 벡터 형식
# ---
# 평면을 **u** 와 **v**에 의해 생성되는 집합으로 표현
#
# **x** = s**u** +  t**v** (s,t $\in$ **R**)
#
# EX) **x** = $x_1$**u** +   $x_2$**v**
#
# ---
# ##3) Solutions of Nonhomogeneous Systems; 비동차계 해집합
# ---
# 해많은 비동차계의 일반해는 동차계를 만복하는 임의의 선형결합을 더한 매게변수 형식으로 표현 가능.
#
# **x** = **p** +  t**v** (t$\in$ **R**)
#
# 즉, Ax=b는 Ax=0해에 벡터 **p**더해서 얻어짐 >> **평행이동**
#
# **Theorem 6**
#
# Ax=b가 **consistent**하고 그해를 **p**라 할때
#
# - Ax=b의 해집합: **w** = **p** + **$v_h$**(Ax=0 임의의해)
# - 단, Ax=b의 nontrivial sol이 적어도 한개 존재해야함
#
# **Writing a Solution Set (of a Consistent System) in Parametric Vector Form**;매개변수 벡터 형식으로 나타내기
#
# RREF << free variable << free variable 로 Write a typical solution << linear combination of vectors (with numeric entries) using the free variables as parameters.

# %% [markdown]
# #**1.7 Linear Independence; 선형독립**
# ---
# ##1) Linear Independence
# ---
# **Definition : Linear Independence**
#
#  $x_1$$v_1$ + $\cdots$ + $x_p$$v_p$ = 0
#
# - linearly independent: only the trivial solution (=only zero vector can be ), 자명한 해만 갖음,영벡터는 선형독립
# - linearly dependent:
#
#   $c_1$$v_1$ + $\cdots$ + $c_p$$v_p$ = 0
#
#     만일 적어도 하나는 영이 아닌 상수 $c_1$,$\cdots$ \,$c_p$인 식을 만족하면 집합{ $v_1$,$\cdots$ \,$v_p$}$\in$**$R^n$**
# 를 linearly dependent라고 함
#
# ---
# ##2) Linear Independence of Matrix Columns; 행렬 열들의 선형독립
# ---
# 벡터 집합 대신 A = [$a_1$,$\cdots$ \,$a_n$]으로 시작 , Ax = 0
#
#  $x_1$$a_1$ + $\cdots$ + $x_p$$a_n$ = 0
#
#  A열들 사이의 선형종속관계는 Ax=0의 nontrivial solution에 대응한다.
#
#  행렬 A의 column이 linear independence인 필요충분 조건은 Ax = 0이  **trivial solution**을 갖는 것이다.
#
# ---
# ##3) Sets of One or Two Vectors; 한개 또는 두개의 벡터로 이루어진 집합
# ---
# {$v_1$,$v_2$}적어도 하나의 벡터가 다른 벡터의 스칼라배인가?
#
# - 1 ; linear dependence;선형종속
#
# ---
# ##4) Sets of Two or More Vectors; 두개 이상의 벡터로 이루어진 집합
# ---
# **Theorem 7 : Characterization of Linearly Dependent Sets**;선형 종속인 집합의 특성
#
# S = [$v_1$,$\cdots$ \,$v_p$] 선형종속일 필요충분조건:
#
# - **적어도 하나**의 벡터가 다른 벡터들의 선형결합이 되는 것이다.
# - 주의: 모든벡터가 앞선 벡터의 선형결합이 아니다.
#
# **Theorem 8**
#
# If a set contains more `vectors` than(>) there are `entries` in each vector, then the set is **linearly dependent.**
#
# ;벡터수(열)이 성분(행) 보다 많을 떄 선형종속
#
# - 이유) free variable $\Rightarrow$ nontrivial sol $\Rightarrow$  dependent
#
# **Theorem 9**
#
# S = [$v_1$,$\cdots$ \,$v_p$]가 **zero vector**를 포함하면 **linearly dependent.**이다.
#
# - 이유) 영벡터는 그 어떤 벡터의 선형결합도 될 수 있음

# %% [markdown]
# #**1.8 Introduction to Linear Transformations; 선형변환 입문**
# ---
# ##1) Linear Transformations
# ---
# $R^n$ ( $x\overset{T}{\to}T(x)$ ) $R^m$
# **transformation (or function or mapping)**;변환
#
# **domain**;정의역,$R^n$
#
# **codomain**;공역, $R^m$
#
# **range**:치역,image들의 집합
#
# **image**:변환된 상,T(x)
#
# ---
# ##2) Matrix Transformations ; 행렬변환
# ---
# T:$R^n$ $\Rightarrow$  $R^m$ ; n열, m행(성분 개수)
#
# X $\longmapsto$ Ax (T(x)=Ax); A는 m x n행렬
#
# **Shear Transformation**; 전단변환
# 선분을 선분으로,정사각형 모서리는 평행사변형의 꼭짓점으로 대응
#
# ---
# ##3) Linear Transformations ; 선형변환
# ---
# **Definition : A transformation (or mapping) is linear if:**
# T가 다음을 만족하면 Linear이라함
# - 1.additivity;벡터함
# - 2.homogeneity;스칼라곱
# - 3. T(0) = 0
# - 4.T(c**u** + d**v**)= cT(**u**) + dT(**v**) ;**superposition**;중첨,만족하면 반드시 선혈
# - 5.T($c_1$**$v_1$** + $\cdots$ +  $c_p$**$v_p$**)= $c_1$T(**$v_1$**)  + $\cdots$ +  $c_P$T(**$v_P$**) ;**superposition**
#
# **Contraction and Dilation**
#
# $R^2$ $\Rightarrow$  $R^2$  , T(x)=rx일때
#
# - Contraction :수축 (0 $\le$ r $\le$ 1)
# - Dilation :팽창 (r > 1)

# %% [markdown]
# #**1.9 The Matrix of a Linear Transformation; 선형변환행렬**
# ---
# ##1)The Matrix of a Linear Transformation
# ---
# **Theorem 10**
#
# Let be a linear transformation. Then there exists a unique matrix
#
# ; 선형변환일 떄 유일한 행렬 존재
#
# **standard matrix**
#
# A = [T($e_1$) $\cdots$ T($e_n$)]
#
# ---
# ##2)Existence and Uniqueness Questions; 존재성과 유일성
# ---
#
# **Definition : onto (전사)**
#
# ; $R^m$에 속하는 각각의 b가 $R^n$에 속하는 적어도 한 x의 상일떄(consistent)
#
# **Definition :  one-to-one (일대일)**
#
# ; $R^m$에 속하는 각각의 b가 x $\in$ $R^n$
#
# **90~92p**
#
# - **Reflections**;onto & one-to-one
#
# - **Contractions and Expansions**;onto & one-to-one
#
# - **Shears**;onto & one-to-one
#
# - **Projections**; **NOT**onto & one-to-one
#
#
# **Theorem 11**
#
# $T$:$R^n$ $\Rightarrow$  $R^m$이 `linear transform`일 때
#
#  $T$가 **one-to-one (일대일)**이 될 필요충분조건:
#
#  - $T(x) = 0 $이 **trivial solution**만을 갖는다.
#
#
# **Theorem 12**
#
# $T$:$R^n$ $\Rightarrow$  $R^m$이 `linear transform`이고 A가 $T$에 대한 standard matrix일 때
#
# - 1.$T$가 **onto (전사)**이 될 필요충분조건:
#
#  - A의 colmns(열들)이 $R^m$을 생성
#
# - 2.$T$가 **one-to-one (일대일)**이 될 필요충분조건:
#  -A의 colmns(열들)이 **linearly independent**
